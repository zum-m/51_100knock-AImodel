# %% [markdown]
# # 第8章 分類モデルの評価を行う10本

# %% [markdown]
# ## ノック71:評価対象のモデルを用意しよう

# %% [markdown]
# ## ノック72:正解率を算出しよう

# %% [markdown]
# ## ノック73:混同行列を見てみよう

# %% [markdown]
# ## ノック74:	適合率を算出しよう

# %% [markdown]
# ## ノック75:再現率を算出しよう

# %% [markdown]
# ## ノック76:F1値を算出しよう

# %% [markdown]
# ## ノック77:分類レポートを見てみよう

# %% [markdown]
# ## ノック78:予測結果の確信度を算出しよう

# %% [markdown]
# ## ノック79:PR曲線を見てみよう

# %% [markdown]
# ## ノック80:各モデルの評価結果を見てみよう
